# %% [markdown]
# ## General stuff (Using the first 2 hours of the month as a sample -- uploaded to teams)

# %%
import pandas as pd

# %%
df1 = pd.read_json('2023-04-01-0.json.gz', lines=True)
df2 = pd.read_json('2023-04-01-1.json.gz', lines=True)

# %%
df1
# Out:
#                  id                           type  \
# 0       28131451238         PullRequestReviewEvent
# 1       28131451239                    DeleteEvent
# 2       28131451240              IssueCommentEvent
# 3       28131451247                      ForkEvent
# 4       28131451251                     WatchEvent
# ...             ...                            ...
# 140835  28131941597                    CreateEvent
# 140836  28131941600                    CreateEvent
# 140837  28131941601                      PushEvent
# 140838  28131944753  PullRequestReviewCommentEvent
# 140839  28131944806  PullRequestReviewCommentEvent
#
#                                                     actor  \
# 0       {'id': 105678611, 'login': 'prawn-test-staging...
# 1       {'id': 19844679, 'login': 'jhsul', 'display_lo...
# 2       {'id': 49699333, 'login': 'dependabot[bot]', '...
# 3       {'id': 48251099, 'login': 'dhaneshwalte', 'dis...
# 4       {'id': 125263927, 'login': 'SmellsGood20', 'di...
# ...                                                   ...
# 140835  {'id': 49699333, 'login': 'dependabot[bot]', '...
# 140836  {'id': 49699333, 'login': 'dependabot[bot]', '...
# 140837  {'id': 70618459, 'login': 'Jsn2win', 'display_...
# 140838  {'id': 977482, 'login': 'myk002', 'display_log...
# 140839  {'id': 977482, 'login': 'myk002', 'display_log...
#
#                                                      repo  \
# 0       {'id': 528452180, 'name': 'prawn-test-staging-...
# 1       {'id': 613192887, 'name': 'jhsul/battle-craft-...
# 2       {'id': 129438177, 'name': 'HCarlos/Moriah', 'u...
# 3       {'id': 5793738, 'name': 'Activiti/Activiti', '...
# 4       {'id': 529537665, 'name': 'Mahmud0808/Iconify'...
# ...                                                   ...
# 140835  {'id': 515870481, 'name': 'touno-io/sso-team',...
# 140836  {'id': 542284349, 'name': 'bennycode/stop-merg...
# 140837  {'id': 364816501, 'name': 'Jsn2win/redesigned-...
# 140838  {'id': 517990, 'name': 'DFHack/dfhack', 'url':...
# 140839  {'id': 517990, 'name': 'DFHack/dfhack', 'url':...
#
#                                                   payload  public  \
# 0       {'action': 'created', 'review': {'id': 1367759...    True
# 1       {'ref': 'ppo-unified-optimizer', 'ref_type': '...    True
# 2       {'action': 'created', 'issue': {'url': 'https:...    True
# 3       {'forkee': {'id': 622033039, 'node_id': 'R_kgD...    True
# 4                                   {'action': 'started'}    True
# ...                                                   ...     ...
# 140835  {'ref': 'dependabot/npm_and_yarn/prettier-2.8....    True
# 140836  {'ref': 'dependabot-npm_and_yarn-main-rimraf-4...    True
# 140837  {'repository_id': 364816501, 'push_id': 131512...    True
# 140838  {'action': 'created', 'comment': {'url': 'http...    True
# 140839  {'action': 'created', 'comment': {'url': 'http...    True
#
#                       created_at  \
# 0      2023-04-01 00:00:00+00:00
# 1      2023-04-01 00:00:00+00:00
# 2      2023-04-01 00:00:00+00:00
# 3      2023-04-01 00:00:00+00:00
# 4      2023-04-01 00:00:00+00:00
# ...                          ...
# 140835 2023-04-01 00:59:59+00:00
# 140836 2023-04-01 00:59:59+00:00
# 140837 2023-04-01 00:59:59+00:00
# 140838 2023-04-01 00:57:21+00:00
# 140839 2023-04-01 00:58:38+00:00
#
#                                                       org
# 0       {'id': 104471395, 'login': 'prawn-test-staging...
# 1                                                     NaN
# 2                                                     NaN
# 3       {'id': 2317879, 'login': 'Activiti', 'gravatar...
# 4                                                     NaN
# ...                                                   ...
# 140835  {'id': 43954870, 'login': 'touno-io', 'gravata...
# 140836                                                NaN
# 140837                                                NaN
# 140838  {'id': 5777323, 'login': 'DFHack', 'gravatar_i...
# 140839  {'id': 5777323, 'login': 'DFHack', 'gravatar_i...
#
# [140840 rows x 8 columns]

# %%
df2
# Out:
#                  id                    type  \
# 0       28131941605               PushEvent
# 1       28131941610        PullRequestEvent
# 2       28131941612               PushEvent
# 3       28131941613  PullRequestReviewEvent
# 4       28131941623             CreateEvent
# ...             ...                     ...
# 144459  28132354078               PushEvent
# 144460  28132354079               PushEvent
# 144461  28132354081               PushEvent
# 144462  28132354085               ForkEvent
# 144463  28132352946               PushEvent
#
#                                                     actor  \
# 0       {'id': 12314515, 'login': 'IanIsMyUsername', '...
# 1       {'id': 49699333, 'login': 'dependabot[bot]', '...
# 2       {'id': 41898282, 'login': 'github-actions[bot]...
# 3       {'id': 41898282, 'login': 'github-actions[bot]...
# 4       {'id': 49699333, 'login': 'dependabot[bot]', '...
# ...                                                   ...
# 144459  {'id': 19688908, 'login': 'zomeru', 'display_l...
# 144460  {'id': 24533979, 'login': 'Hopekz', 'display_l...
# 144461  {'id': 107725949, 'login': 'Icastroo', 'displa...
# 144462  {'id': 18144508, 'login': 'AceLuodan', 'displa...
# 144463  {'id': 18511288, 'login': 'ThatWileyGuy', 'dis...
#
#                                                      repo  \
# 0       {'id': 621598270, 'name': 'IanIsMyUsername/tra...
# 1       {'id': 542284349, 'name': 'bennycode/stop-merg...
# 2       {'id': 610752531, 'name': 'Rolddor/rolddor', '...
# 3       {'id': 205136166, 'name': 'bennycode/ts-node-s...
# 4       {'id': 459025965, 'name': 'apache/incubator-op...
# ...                                                   ...
# 144459  {'id': 356011647, 'name': 'zomeru/zomeru', 'ur...
# 144460  {'id': 287118360, 'name': 'Hopekz/CEV-Eris', '...
# 144461  {'id': 613143690, 'name': 'Icastroo/huddle-lan...
# 144462  {'id': 619859161, 'name': 'twitter/the-algorit...
# 144463  {'id': 56427466, 'name': 'ThatWileyGuy/ghostpd...
#
#                                                   payload  public  \
# 0       {'repository_id': 621598270, 'push_id': 131512...    True
# 1       {'action': 'opened', 'number': 54, 'pull_reque...    True
# 2       {'repository_id': 610752531, 'push_id': 131512...    True
# 3       {'action': 'created', 'review': {'id': 1367783...    True
# 4       {'ref': 'dependabot/cargo/opentelemetry-jaeger...    True
# ...                                                   ...     ...
# 144459  {'repository_id': 356011647, 'push_id': 131514...    True
# 144460  {'repository_id': 287118360, 'push_id': 131514...    True
# 144461  {'repository_id': 613143690, 'push_id': 131514...    True
# 144462  {'forkee': {'id': 622055388, 'node_id': 'R_kgD...    True
# 144463  {'repository_id': 56427466, 'push_id': 1315148...    True
#
#                       created_at  \
# 0      2023-04-01 01:00:00+00:00
# 1      2023-04-01 01:00:00+00:00
# 2      2023-04-01 01:00:00+00:00
# 3      2023-04-01 01:00:00+00:00
# 4      2023-04-01 01:00:00+00:00
# ...                          ...
# 144459 2023-04-01 01:59:59+00:00
# 144460 2023-04-01 01:59:59+00:00
# 144461 2023-04-01 01:59:59+00:00
# 144462 2023-04-01 01:59:59+00:00
# 144463 2023-04-01 01:59:51+00:00
#
#                                                       org
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4       {'id': 47359, 'login': 'apache', 'gravatar_id'...
# ...                                                   ...
# 144459                                                NaN
# 144460                                                NaN
# 144461                                                NaN
# 144462  {'id': 50278, 'login': 'twitter', 'gravatar_id...
# 144463                                                NaN
#
# [144464 rows x 8 columns]

# %%
concatenated_df = pd.concat([df1, df2], ignore_index=True)

# %%
concatenated_df
# Out:
#                  id                    type  \
# 0       28131451238  PullRequestReviewEvent
# 1       28131451239             DeleteEvent
# 2       28131451240       IssueCommentEvent
# 3       28131451247               ForkEvent
# 4       28131451251              WatchEvent
# ...             ...                     ...
# 285299  28132354078               PushEvent
# 285300  28132354079               PushEvent
# 285301  28132354081               PushEvent
# 285302  28132354085               ForkEvent
# 285303  28132352946               PushEvent
#
#                                                     actor  \
# 0       {'id': 105678611, 'login': 'prawn-test-staging...
# 1       {'id': 19844679, 'login': 'jhsul', 'display_lo...
# 2       {'id': 49699333, 'login': 'dependabot[bot]', '...
# 3       {'id': 48251099, 'login': 'dhaneshwalte', 'dis...
# 4       {'id': 125263927, 'login': 'SmellsGood20', 'di...
# ...                                                   ...
# 285299  {'id': 19688908, 'login': 'zomeru', 'display_l...
# 285300  {'id': 24533979, 'login': 'Hopekz', 'display_l...
# 285301  {'id': 107725949, 'login': 'Icastroo', 'displa...
# 285302  {'id': 18144508, 'login': 'AceLuodan', 'displa...
# 285303  {'id': 18511288, 'login': 'ThatWileyGuy', 'dis...
#
#                                                      repo  \
# 0       {'id': 528452180, 'name': 'prawn-test-staging-...
# 1       {'id': 613192887, 'name': 'jhsul/battle-craft-...
# 2       {'id': 129438177, 'name': 'HCarlos/Moriah', 'u...
# 3       {'id': 5793738, 'name': 'Activiti/Activiti', '...
# 4       {'id': 529537665, 'name': 'Mahmud0808/Iconify'...
# ...                                                   ...
# 285299  {'id': 356011647, 'name': 'zomeru/zomeru', 'ur...
# 285300  {'id': 287118360, 'name': 'Hopekz/CEV-Eris', '...
# 285301  {'id': 613143690, 'name': 'Icastroo/huddle-lan...
# 285302  {'id': 619859161, 'name': 'twitter/the-algorit...
# 285303  {'id': 56427466, 'name': 'ThatWileyGuy/ghostpd...
#
#                                                   payload  public  \
# 0       {'action': 'created', 'review': {'id': 1367759...    True
# 1       {'ref': 'ppo-unified-optimizer', 'ref_type': '...    True
# 2       {'action': 'created', 'issue': {'url': 'https:...    True
# 3       {'forkee': {'id': 622033039, 'node_id': 'R_kgD...    True
# 4                                   {'action': 'started'}    True
# ...                                                   ...     ...
# 285299  {'repository_id': 356011647, 'push_id': 131514...    True
# 285300  {'repository_id': 287118360, 'push_id': 131514...    True
# 285301  {'repository_id': 613143690, 'push_id': 131514...    True
# 285302  {'forkee': {'id': 622055388, 'node_id': 'R_kgD...    True
# 285303  {'repository_id': 56427466, 'push_id': 1315148...    True
#
#                       created_at  \
# 0      2023-04-01 00:00:00+00:00
# 1      2023-04-01 00:00:00+00:00
# 2      2023-04-01 00:00:00+00:00
# 3      2023-04-01 00:00:00+00:00
# 4      2023-04-01 00:00:00+00:00
# ...                          ...
# 285299 2023-04-01 01:59:59+00:00
# 285300 2023-04-01 01:59:59+00:00
# 285301 2023-04-01 01:59:59+00:00
# 285302 2023-04-01 01:59:59+00:00
# 285303 2023-04-01 01:59:51+00:00
#
#                                                       org
# 0       {'id': 104471395, 'login': 'prawn-test-staging...
# 1                                                     NaN
# 2                                                     NaN
# 3       {'id': 2317879, 'login': 'Activiti', 'gravatar...
# 4                                                     NaN
# ...                                                   ...
# 285299                                                NaN
# 285300                                                NaN
# 285301                                                NaN
# 285302  {'id': 50278, 'login': 'twitter', 'gravatar_id...
# 285303                                                NaN
#
# [285304 rows x 8 columns]

# %%
concatenated_df['actor'][2]
# Out:
# {'id': 49699333,
#  'login': 'dependabot[bot]',
#  'display_login': 'dependabot',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/dependabot[bot]',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'}

# %% [markdown]
# ## Email Analysis

# %%
import json
from graphqlclient import GraphQLClient

access_token = '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'
endpoint_url = 'https://api.github.com/graphql'
client = GraphQLClient(endpoint_url)
client.inject_token('Bearer ' + access_token)

def get_user_email(username):
    query = """
    query($username: String!) {
      user(login: $username) {
        email
      }
    }
    """
    variables = {"username": username}

    result = client.execute(query, variables)
    response_json = json.loads(result)

    if "errors" in response_json:
        error_message = response_json.get("errors")[0].get("message")
        print(f"Error querying user {username}: {error_message}")
        return None

    data = response_json["data"]["user"]
    email = data.get("email")
    return email


emails = []
for row in concatenated_df['actor']:
    login = row.get('login')
    if login:
        email = get_user_email(login)
        if email:
            emails.append(email)
        else:
            print(f"No email found for user {login}")

print(emails)
# Out:
# Error querying user prawn-test-staging-rw[bot]: Could not resolve to a User with the login of 'prawn-test-staging-rw[bot]'.
# No email found for user prawn-test-staging-rw[bot]
# Error querying user dependabot[bot]: Could not resolve to a User with the login of 'dependabot[bot]'.
# No email found for user dependabot[bot]
# No email found for user dhaneshwalte
# No email found for user SmellsGood20
# Error querying user pull[bot]: Could not resolve to a User with the login of 'pull[bot]'.
# No email found for user pull[bot]
# No email found for user PotatoesSkill
# Error querying user github-actions[bot]: Could not resolve to a User with the login of 'github-actions[bot]'.
# No email found for user github-actions[bot]
# Error querying user github-classroom[bot]: Could not resolve to a User with the login of 'github-classroom[bot]'.
# No email found for user github-classroom[bot]
# No email found for user russll
# No email found for user Newdevs2023
# Error querying user vercel[bot]: Could not resolve to a User with the login of 'vercel[bot]'.
# No email found for user vercel[bot]
# Error querying user github-actions[bot]: Could not resolve to a User with the login of 'github-actions[bot]'.
# No email found for user github-actions[bot]
# Error querying user dependabot[bot]: Could not resolve to a User with the login of 'dependabot[bot]'.
# No email found for user dependabot[bot]
# Error querying user github-actions[bot]: Could not resolve to a User with the login of 'github-actions[bot]'.
# No email found for user github-actions[bot]
# No email found for user PiotrKupis999
# No email found for user Selenityy
# No email found for user Ar1stotele
# Error querying user dependabot[bot]: Could not resolve to a User with the login of 'dependabot[bot]'.
# No email found for user dependabot[bot]
# Error querying user github-actions[bot]: Could not resolve to a User with the login of 'github-actions[bot]'.
# No email found for user github-actions[bot]
# Error querying user dependabot[bot]: Could not resolve to a User with the login of 'dependabot[bot]'.
# No email found for user dependabot[bot]
# No email found for user Kaoutar-boudouft
# No email found for user blackhawk70
# Error querying user dependabot[bot]: Could not resolve to a User with the login of 'dependabot[bot]'.
# No email found for user dependabot[bot]
# No email found for user Harshal609
# No email found for user Cyogbang
# No email found for user PotatoesSkill
# No email found for user Imy2003
# Error querying user github-actions[bot]: Could not resolve to a User with the login of 'github-actions[bot]'.
# No email found for user github-actions[bot]
# No email found for user GyrmyzyK30
# No email found for user tseladev
# Error querying user aws-connector-for-github[bot]: Could not resolve to a User with the login of 'aws-connector-for-github[bot]'.
# No email found for user aws-connector-for-github[bot]
# Error querying user pull[bot]: Could not resolve to a User with the login of 'pull[bot]'.
# No email found for user pull[bot]
# No email found for user rustgen
# Error querying user dependabot[bot]: Could not resolve to a User with the login of 'dependabot[bot]'.
# No email found for user dependabot[bot]
# No email found for user Harshal609
# Error querying user renovate[bot]: Could not resolve to a User with the login of 'renovate[bot]'.
# No email found for user renovate[bot]
# No email found for user tigers40
# Error querying user KookerFoxYT: Could not resolve to a User with the login of 'KookerFoxYT'.
# No email found for user KookerFoxYT
# No email found for user hackernews-archive
# No email found for user maxmielchen
# Error querying user dependabot[bot]: Could not resolve to a User with the login of 'dependabot[bot]'.
# No email found for user dependabot[bot]
# No email found for user galvana
# Error querying user github-classroom[bot]: Could not resolve to a User with the login of 'github-classroom[bot]'.
# No email found for user github-classroom[bot]
# No email found for user guihkx
# No email found for user ChrisF03
# Error querying user github-actions[bot]: Could not resolve to a User with the login of 'github-actions[bot]'.
# No email found for user github-actions[bot]
# No email found for user avanhoveln-BITCO
# No email found for user Mansur9
# No email found for user tuckerpikula
# No email found for user Dtaylor1333
# No email found for user jpgard
# Error querying user mikelgoti: Could not resolve to a User with the login of 'mikelgoti'.
# No email found for user mikelgoti
# Error querying user dependabot[bot]: Could not resolve to a User with the login of 'dependabot[bot]'.
# No email found for user dependabot[bot]
# No email found for user yeolip
# Error querying user trunk-dev[bot]: Could not resolve to a User with the login of 'trunk-dev[bot]'.
# No email found for user trunk-dev[bot]
# No email found for user sergiolluvap
# No email found for user PeteFloyd
# No email found for user sergiolluvap
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [16], in <cell line: 40>()
#      41 login = row.get('login')
#      42 if login:
# ---> 43     email = get_user_email(login)
#      44     if email:
#      45         emails.append(email)
#
# Input In [16], in get_user_email(username)
#      16 query = """
#      17 query($username: String!) {
#      18   user(login: $username) {
#    (...)
#      21 }
#      22 """
#      23 variables = {"username": username}
# ---> 25 result = client.execute(query, variables)
#      26 response_json = json.loads(result)
#      28 if "errors" in response_json:
#
# File D:\Anaconda\lib\site-packages\graphqlclient\client.py:11, in GraphQLClient.execute(self, query, variables)
#      10 def execute(self, query, variables=None):
# ---> 11     return self._send(query, variables)
#
# File D:\Anaconda\lib\site-packages\graphqlclient\client.py:29, in GraphQLClient._send(self, query, variables)
#      26 req = urllib.request.Request(self.endpoint, json.dumps(data).encode('utf-8'), headers)
#      28 try:
# ---> 29     response = urllib.request.urlopen(req)
#      30     return response.read().decode('utf-8')
#      31 except urllib.error.HTTPError as e:
#
# File D:\Anaconda\lib\urllib\request.py:214, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212 else:
#     213     opener = _opener
# --> 214 return opener.open(url, data, timeout)
#
# File D:\Anaconda\lib\urllib\request.py:517, in OpenerDirector.open(self, fullurl, data, timeout)
#     514     req = meth(req)
#     516 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 517 response = self._open(req, data)
#     519 # post-process response
#     520 meth_name = protocol+"_response"
#
# File D:\Anaconda\lib\urllib\request.py:534, in OpenerDirector._open(self, req, data)
#     531     return result
#     533 protocol = req.type
# --> 534 result = self._call_chain(self.handle_open, protocol, protocol +
#     535                           '_open', req)
#     536 if result:
#     537     return result
#
# File D:\Anaconda\lib\urllib\request.py:494, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     492 for handler in handlers:
#     493     func = getattr(handler, meth_name)
# --> 494     result = func(*args)
#     495     if result is not None:
#     496         return result
#
# File D:\Anaconda\lib\urllib\request.py:1389, in HTTPSHandler.https_open(self, req)
#    1388 def https_open(self, req):
# -> 1389     return self.do_open(http.client.HTTPSConnection, req,
#    1390         context=self._context, check_hostname=self._check_hostname)
#
# File D:\Anaconda\lib\urllib\request.py:1346, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1344 try:
#    1345     try:
# -> 1346         h.request(req.get_method(), req.selector, req.data, headers,
#    1347                   encode_chunked=req.has_header('Transfer-encoding'))
#    1348     except OSError as err: # timeout error
#    1349         raise URLError(err)
#
# File D:\Anaconda\lib\http\client.py:1285, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1282 def request(self, method, url, body=None, headers={}, *,
#    1283             encode_chunked=False):
#    1284     """Send a complete request to the server."""
# -> 1285     self._send_request(method, url, body, headers, encode_chunked)
#
# File D:\Anaconda\lib\http\client.py:1331, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1327 if isinstance(body, str):
#    1328     # RFC 2616 Section 3.7.1 says that text default has a
#    1329     # default charset of iso-8859-1.
#    1330     body = _encode(body, 'body')
# -> 1331 self.endheaders(body, encode_chunked=encode_chunked)
#
# File D:\Anaconda\lib\http\client.py:1280, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1278 else:
#    1279     raise CannotSendHeader()
# -> 1280 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File D:\Anaconda\lib\http\client.py:1040, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1038 msg = b"\r\n".join(self._buffer)
#    1039 del self._buffer[:]
# -> 1040 self.send(msg)
#    1042 if message_body is not None:
#    1043
#    1044     # create a consistent interface to message_body
#    1045     if hasattr(message_body, 'read'):
#    1046         # Let file-like take precedence over byte-like.  This
#    1047         # is needed to allow the current position of mmap'ed
#    1048         # files to be taken into account.
#
# File D:\Anaconda\lib\http\client.py:980, in HTTPConnection.send(self, data)
#     978 if self.sock is None:
#     979     if self.auto_open:
# --> 980         self.connect()
#     981     else:
#     982         raise NotConnected()
#
# File D:\Anaconda\lib\http\client.py:1447, in HTTPSConnection.connect(self)
#    1444 def connect(self):
#    1445     "Connect to a host on a given (SSL) port."
# -> 1447     super().connect()
#    1449     if self._tunnel_host:
#    1450         server_hostname = self._tunnel_host
#
# File D:\Anaconda\lib\http\client.py:946, in HTTPConnection.connect(self)
#     944 def connect(self):
#     945     """Connect to the host and port specified in __init__."""
# --> 946     self.sock = self._create_connection(
#     947         (self.host,self.port), self.timeout, self.source_address)
#     948     # Might fail in OSs that don't implement TCP_NODELAY
#     949     try:
#
# File D:\Anaconda\lib\socket.py:823, in create_connection(address, timeout, source_address)
#     821 host, port = address
#     822 err = None
# --> 823 for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     824     af, socktype, proto, canonname, sa = res
#     825     sock = None
#
# File D:\Anaconda\lib\socket.py:954, in getaddrinfo(host, port, family, type, proto, flags)
#     951 # We override this function since we want to translate the numeric family
#     952 # and socket type values to enum constants.
#     953 addrlist = []
# --> 954 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     955     af, socktype, proto, canonname, sa = res
#     956     addrlist.append((_intenum_converter(af, AddressFamily),
#     957                      _intenum_converter(socktype, SocketKind),
#     958                      proto, canonname, sa))
#
# KeyboardInterrupt:

# %%
print(emails)
# Out:
# ['me@jackhsullivan.com', 'bot@lombiq.com', 'eduardovictor28@gmail.com', 'fariaislam258@gmail.com', 'cetinmutluonal@gmail.com', 'falktx@falktx.com', 'srleecode@gmail.com', 'diamond.po.central@gmail.com', 'cetinmutluonal@gmail.com', 'bot@lombiq.com', 'srichandraallala@gmail.com', 'scott.horowitz@nrel.gov', 'husainazkas@gmail.com', 'mohannad.otaibi@gmail.com', 'bot@lombiq.com', 'husainazkas@gmail.com', 'trev.norris@gmail.com', 'smolloy@microsoft.com', 'jsmith@webinertia.net', 'smolloy@microsoft.com', 'bot@lombiq.com', 'jsmith@webinertia.net', 'vizicist@gmail.com']

# %%
it_emails = []

for email in emails:
    if email.endswith(".ca"):
        it_emails.append(email)

print("Emails ending with '.it':")
for it_email in it_emails:
    print(it_email)

count_it_emails = len(it_emails)
print(f"Number of emails ending with '.it': {count_it_emails}")
# Out:
# Emails ending with '.it':
# Number of emails ending with '.it': 0

# %% [markdown]
# ## Getting rid of Github Bot commits

# %%
filtered_df = concatenated_df[~concatenated_df['actor'].apply(lambda x: x.get('login').endswith('[bot]'))]
filtered_df
# Out:
#                  id         type  \
# 1       28131451239  DeleteEvent
# 3       28131451247    ForkEvent
# 4       28131451251   WatchEvent
# 6       28131451262    PushEvent
# 7       28131451264    PushEvent
# ...             ...          ...
# 285299  28132354078    PushEvent
# 285300  28132354079    PushEvent
# 285301  28132354081    PushEvent
# 285302  28132354085    ForkEvent
# 285303  28132352946    PushEvent
#
#                                                     actor  \
# 1       {'id': 19844679, 'login': 'jhsul', 'display_lo...
# 3       {'id': 48251099, 'login': 'dhaneshwalte', 'dis...
# 4       {'id': 125263927, 'login': 'SmellsGood20', 'di...
# 6       {'id': 75749677, 'login': 'PotatoesSkill', 'di...
# 7       {'id': 8517910, 'login': 'LombiqBot', 'display...
# ...                                                   ...
# 285299  {'id': 19688908, 'login': 'zomeru', 'display_l...
# 285300  {'id': 24533979, 'login': 'Hopekz', 'display_l...
# 285301  {'id': 107725949, 'login': 'Icastroo', 'displa...
# 285302  {'id': 18144508, 'login': 'AceLuodan', 'displa...
# 285303  {'id': 18511288, 'login': 'ThatWileyGuy', 'dis...
#
#                                                      repo  \
# 1       {'id': 613192887, 'name': 'jhsul/battle-craft-...
# 3       {'id': 5793738, 'name': 'Activiti/Activiti', '...
# 4       {'id': 529537665, 'name': 'Mahmud0808/Iconify'...
# 6       {'id': 605828707, 'name': 'PotatoesSkill/2', '...
# 7       {'id': 86929735, 'name': 'Lombiq/Orchard', 'ur...
# ...                                                   ...
# 285299  {'id': 356011647, 'name': 'zomeru/zomeru', 'ur...
# 285300  {'id': 287118360, 'name': 'Hopekz/CEV-Eris', '...
# 285301  {'id': 613143690, 'name': 'Icastroo/huddle-lan...
# 285302  {'id': 619859161, 'name': 'twitter/the-algorit...
# 285303  {'id': 56427466, 'name': 'ThatWileyGuy/ghostpd...
#
#                                                   payload  public  \
# 1       {'ref': 'ppo-unified-optimizer', 'ref_type': '...    True
# 3       {'forkee': {'id': 622033039, 'node_id': 'R_kgD...    True
# 4                                   {'action': 'started'}    True
# 6       {'repository_id': 605828707, 'push_id': 131509...    True
# 7       {'repository_id': 86929735, 'push_id': 1315095...    True
# ...                                                   ...     ...
# 285299  {'repository_id': 356011647, 'push_id': 131514...    True
# 285300  {'repository_id': 287118360, 'push_id': 131514...    True
# 285301  {'repository_id': 613143690, 'push_id': 131514...    True
# 285302  {'forkee': {'id': 622055388, 'node_id': 'R_kgD...    True
# 285303  {'repository_id': 56427466, 'push_id': 1315148...    True
#
#                       created_at  \
# 1      2023-04-01 00:00:00+00:00
# 3      2023-04-01 00:00:00+00:00
# 4      2023-04-01 00:00:00+00:00
# 6      2023-04-01 00:00:00+00:00
# 7      2023-04-01 00:00:00+00:00
# ...                          ...
# 285299 2023-04-01 01:59:59+00:00
# 285300 2023-04-01 01:59:59+00:00
# 285301 2023-04-01 01:59:59+00:00
# 285302 2023-04-01 01:59:59+00:00
# 285303 2023-04-01 01:59:51+00:00
#
#                                                       org
# 1                                                     NaN
# 3       {'id': 2317879, 'login': 'Activiti', 'gravatar...
# 4                                                     NaN
# 6                                                     NaN
# 7       {'id': 8158177, 'login': 'Lombiq', 'gravatar_i...
# ...                                                   ...
# 285299                                                NaN
# 285300                                                NaN
# 285301                                                NaN
# 285302  {'id': 50278, 'login': 'twitter', 'gravatar_id...
# 285303                                                NaN
#
# [182994 rows x 8 columns]

# %%
filtered_df.reset_index(drop=True, inplace=True)

# %%
filtered_df['repo'][0]
# Out:
# {'id': 613192887,
#  'name': 'jhsul/battle-craft-rl',
#  'url': 'https://api.github.com/repos/jhsul/battle-craft-rl'}

# %%
filtered_df['payload'][0]
# Out:
# {'ref': 'ppo-unified-optimizer', 'ref_type': 'branch', 'pusher_type': 'user'}

# %% [markdown]
# ## Email Analysis with Resulting dataframe only consisting of users with .it emails (Testing to see if it works with only the first ".it" email that shows up)

# %%
def get_user_email(username):
    query = """
    query($username: String!) {
      user(login: $username) {
        email
      }
    }
    """
    variables = {"username": username}

    result = client.execute(query, variables)
    response_json = json.loads(result)

    if "errors" in response_json:
        error_message = response_json.get("errors")[0].get("message")
        print(f"Error querying user {username}: {error_message}")
        return None

    data = response_json["data"]["user"]
    email = data.get("email")
    return email

first_email_with_it = None
for i, row in enumerate(concatenated_df['actor']):
    login = row.get('login')
    if login:
        email = get_user_email(login)
        if email and email.endswith('.ca'):
            first_email_with_it = email
            break

if first_email_with_it:
    new_dataset = concatenated_df.iloc[[i]]
    print(new_dataset)
else:
    print("No email ending with '.it' found in the dataset")
# Out:
# Error querying user prawn-test-staging-rw[bot]: Could not resolve to a User with the login of 'prawn-test-staging-rw[bot]'.
# Error querying user dependabot[bot]: Could not resolve to a User with the login of 'dependabot[bot]'.
# Error querying user pull[bot]: Could not resolve to a User with the login of 'pull[bot]'.
# Error querying user github-actions[bot]: Could not resolve to a User with the login of 'github-actions[bot]'.
# Error querying user github-classroom[bot]: Could not resolve to a User with the login of 'github-classroom[bot]'.
# Error querying user vercel[bot]: Could not resolve to a User with the login of 'vercel[bot]'.
# Error querying user github-actions[bot]: Could not resolve to a User with the login of 'github-actions[bot]'.
# Error querying user dependabot[bot]: Could not resolve to a User with the login of 'dependabot[bot]'.
# Error querying user github-actions[bot]: Could not resolve to a User with the login of 'github-actions[bot]'.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [23], in <cell line: 27>()
#      28 login = row.get('login')
#      29 if login:
# ---> 30     email = get_user_email(login)
#      31     if email and email.endswith('.ca'):
#      32         first_email_with_it = email
#
# Input In [23], in get_user_email(username)
#       3 query = """
#       4 query($username: String!) {
#       5   user(login: $username) {
#    (...)
#       8 }
#       9 """
#      10 variables = {"username": username}
# ---> 12 result = client.execute(query, variables)
#      13 response_json = json.loads(result)
#      15 if "errors" in response_json:
#
# File D:\Anaconda\lib\site-packages\graphqlclient\client.py:11, in GraphQLClient.execute(self, query, variables)
#      10 def execute(self, query, variables=None):
# ---> 11     return self._send(query, variables)
#
# File D:\Anaconda\lib\site-packages\graphqlclient\client.py:29, in GraphQLClient._send(self, query, variables)
#      26 req = urllib.request.Request(self.endpoint, json.dumps(data).encode('utf-8'), headers)
#      28 try:
# ---> 29     response = urllib.request.urlopen(req)
#      30     return response.read().decode('utf-8')
#      31 except urllib.error.HTTPError as e:
#
# File D:\Anaconda\lib\urllib\request.py:214, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212 else:
#     213     opener = _opener
# --> 214 return opener.open(url, data, timeout)
#
# File D:\Anaconda\lib\urllib\request.py:517, in OpenerDirector.open(self, fullurl, data, timeout)
#     514     req = meth(req)
#     516 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 517 response = self._open(req, data)
#     519 # post-process response
#     520 meth_name = protocol+"_response"
#
# File D:\Anaconda\lib\urllib\request.py:534, in OpenerDirector._open(self, req, data)
#     531     return result
#     533 protocol = req.type
# --> 534 result = self._call_chain(self.handle_open, protocol, protocol +
#     535                           '_open', req)
#     536 if result:
#     537     return result
#
# File D:\Anaconda\lib\urllib\request.py:494, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     492 for handler in handlers:
#     493     func = getattr(handler, meth_name)
# --> 494     result = func(*args)
#     495     if result is not None:
#     496         return result
#
# File D:\Anaconda\lib\urllib\request.py:1389, in HTTPSHandler.https_open(self, req)
#    1388 def https_open(self, req):
# -> 1389     return self.do_open(http.client.HTTPSConnection, req,
#    1390         context=self._context, check_hostname=self._check_hostname)
#
# File D:\Anaconda\lib\urllib\request.py:1346, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1344 try:
#    1345     try:
# -> 1346         h.request(req.get_method(), req.selector, req.data, headers,
#    1347                   encode_chunked=req.has_header('Transfer-encoding'))
#    1348     except OSError as err: # timeout error
#    1349         raise URLError(err)
#
# File D:\Anaconda\lib\http\client.py:1285, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1282 def request(self, method, url, body=None, headers={}, *,
#    1283             encode_chunked=False):
#    1284     """Send a complete request to the server."""
# -> 1285     self._send_request(method, url, body, headers, encode_chunked)
#
# File D:\Anaconda\lib\http\client.py:1331, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1327 if isinstance(body, str):
#    1328     # RFC 2616 Section 3.7.1 says that text default has a
#    1329     # default charset of iso-8859-1.
#    1330     body = _encode(body, 'body')
# -> 1331 self.endheaders(body, encode_chunked=encode_chunked)
#
# File D:\Anaconda\lib\http\client.py:1280, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1278 else:
#    1279     raise CannotSendHeader()
# -> 1280 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File D:\Anaconda\lib\http\client.py:1040, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1038 msg = b"\r\n".join(self._buffer)
#    1039 del self._buffer[:]
# -> 1040 self.send(msg)
#    1042 if message_body is not None:
#    1043
#    1044     # create a consistent interface to message_body
#    1045     if hasattr(message_body, 'read'):
#    1046         # Let file-like take precedence over byte-like.  This
#    1047         # is needed to allow the current position of mmap'ed
#    1048         # files to be taken into account.
#
# File D:\Anaconda\lib\http\client.py:980, in HTTPConnection.send(self, data)
#     978 if self.sock is None:
#     979     if self.auto_open:
# --> 980         self.connect()
#     981     else:
#     982         raise NotConnected()
#
# File D:\Anaconda\lib\http\client.py:1447, in HTTPSConnection.connect(self)
#    1444 def connect(self):
#    1445     "Connect to a host on a given (SSL) port."
# -> 1447     super().connect()
#    1449     if self._tunnel_host:
#    1450         server_hostname = self._tunnel_host
#
# File D:\Anaconda\lib\http\client.py:946, in HTTPConnection.connect(self)
#     944 def connect(self):
#     945     """Connect to the host and port specified in __init__."""
# --> 946     self.sock = self._create_connection(
#     947         (self.host,self.port), self.timeout, self.source_address)
#     948     # Might fail in OSs that don't implement TCP_NODELAY
#     949     try:
#
# File D:\Anaconda\lib\socket.py:832, in create_connection(address, timeout, source_address)
#     830 if source_address:
#     831     sock.bind(source_address)
# --> 832 sock.connect(sa)
#     833 # Break explicitly a reference cycle
#     834 err = None
#
# KeyboardInterrupt:

# %%
new_dataset

# %%
get_user_email('francisbilo')
# Out:
# 'francis.bilodeau-lecomte@polymtl.ca'

# %% [markdown]
# ## Getting repository languages from API

# %%
def get_repository_languages(owner, name):
    query = """
    query($owner: String!, $name: String!) {
      repository(owner: $owner, name: $name) {
        name
        languages(first: 10) {
          nodes {
            name
          }
        }
      }
    }
    """
    variables = {"owner": owner, "name": name}

    result = client.execute(query, variables)
    response_json = json.loads(result)

    if "errors" in response_json:
        error_message = response_json.get("errors")[0].get("message")
        print(f"Error querying repository languages: {error_message}")
        return None

    repository = response_json["data"]["repository"]
    languages = repository["languages"]["nodes"]
    return languages

# %%
get_repository_languages('jhsul','battle-craft-rl')
# Out:
# [{'name': 'Python'}]

# %% [markdown]
# ## Get new Dataframe made only of repos that have Python as language (Unfinished on the new dataframe creation part, still dodgy and only 50 to test)

# %%
def get_repository_languages(owner, name):
    query = """
    query($owner: String!, $name: String!) {
      repository(owner: $owner, name: $name) {
        name
        languages(first: 10) {
          nodes {
            name
          }
        }
      }
    }
    """
    variables = {"owner": owner, "name": name}

    result = client.execute(query, variables)
    response_json = json.loads(result)

    if "errors" in response_json:
        error_message = response_json.get("errors")[0].get("message")
        print(f"Error querying repository languages: {error_message}")
        return None

    repository = response_json["data"]["repository"]
    languages = repository["languages"]["nodes"]
    return languages

python_repositories_df = filtered_df[[]]  

for index, repo_data in filtered_df.iterrows():
    if index >= 50:
        break 
    
    repo_info = repo_data['repo']
    print(repo_info)
    repo_id = repo_info['id']
    repo_stuff = repo_info['name'].split('/')
    repo_owner = repo_stuff[0]
    repo_name = repo_stuff[1]

   
    repository_languages = get_repository_languages(repo_owner, repo_name)

    if repository_languages:
        python_language_present = any(lang['name'] == 'Python' for lang in repository_languages)

        if python_language_present:
            python_repositories_df = python_repositories_df.append(repo_data, ignore_index=True)


print(python_repositories_df)
# Out:
# {'id': 613192887, 'name': 'jhsul/battle-craft-rl', 'url': 'https://api.github.com/repos/jhsul/battle-craft-rl'}
# C:\Users\Guilherme\AppData\Local\Temp\ipykernel_8308\997953705.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   python_repositories_df = python_repositories_df.append(repo_data, ignore_index=True)
# {'id': 5793738, 'name': 'Activiti/Activiti', 'url': 'https://api.github.com/repos/Activiti/Activiti'}
# {'id': 529537665, 'name': 'Mahmud0808/Iconify', 'url': 'https://api.github.com/repos/Mahmud0808/Iconify'}
# {'id': 605828707, 'name': 'PotatoesSkill/2', 'url': 'https://api.github.com/repos/PotatoesSkill/2'}
# {'id': 86929735, 'name': 'Lombiq/Orchard', 'url': 'https://api.github.com/repos/Lombiq/Orchard'}
# {'id': 615882673, 'name': 'lm-sys/FastChat', 'url': 'https://api.github.com/repos/lm-sys/FastChat'}
# C:\Users\Guilherme\AppData\Local\Temp\ipykernel_8308\997953705.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   python_repositories_df = python_repositories_df.append(repo_data, ignore_index=True)
# {'id': 611466714, 'name': 'Newdevs2023/medical_group', 'url': 'https://api.github.com/repos/Newdevs2023/medical_group'}
# {'id': 569842541, 'name': 'xfire741/algafood-api', 'url': 'https://api.github.com/repos/xfire741/algafood-api'}
# {'id': 620347929, 'name': 'PiotrKupis999/UnfairTower', 'url': 'https://api.github.com/repos/PiotrKupis999/UnfairTower'}
# {'id': 617211216, 'name': 'Selenityy/To-Do-List', 'url': 'https://api.github.com/repos/Selenityy/To-Do-List'}
# {'id': 622030323, 'name': 'Ar1stotele/Hackathon-Spring-2023', 'url': 'https://api.github.com/repos/Ar1stotele/Hackathon-Spring-2023'}
# C:\Users\Guilherme\AppData\Local\Temp\ipykernel_8308\997953705.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   python_repositories_df = python_repositories_df.append(repo_data, ignore_index=True)
# {'id': 622033042, 'name': 'faria-islam-mily/c-programming', 'url': 'https://api.github.com/repos/faria-islam-mily/c-programming'}
# {'id': 622031955, 'name': 'Kaoutar-boudouft/Invited', 'url': 'https://api.github.com/repos/Kaoutar-boudouft/Invited'}
# Error querying repository languages: Could not resolve to a Repository with the name 'Kaoutar-boudouft/Invited'.
# {'id': 588983497, 'name': 'blackhawk70/blackhawk70.github.io', 'url': 'https://api.github.com/repos/blackhawk70/blackhawk70.github.io'}
# {'id': 617597198, 'name': 'CetinMutluOnal/DiemSocial-Backend', 'url': 'https://api.github.com/repos/CetinMutluOnal/DiemSocial-Backend'}
# {'id': 542710804, 'name': '499CSpeaking/SpeakingPortal', 'url': 'https://api.github.com/repos/499CSpeaking/SpeakingPortal'}
# C:\Users\Guilherme\AppData\Local\Temp\ipykernel_8308\997953705.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   python_repositories_df = python_repositories_df.append(repo_data, ignore_index=True)
# {'id': 619484802, 'name': 'AidaDSP/aida-x', 'url': 'https://api.github.com/repos/AidaDSP/aida-x'}
# {'id': 294132374, 'name': 'srleecode/domain', 'url': 'https://api.github.com/repos/srleecode/domain'}
# {'id': 616870478, 'name': 'Cyogbang/alx-low_level_programming', 'url': 'https://api.github.com/repos/Cyogbang/alx-low_level_programming'}
# {'id': 610277664, 'name': 'PotatoesSkill/3', 'url': 'https://api.github.com/repos/PotatoesSkill/3'}
# {'id': 617432319, 'name': 'Imy2003/alx-low_level_programming', 'url': 'https://api.github.com/repos/Imy2003/alx-low_level_programming'}
# {'id': 11110385, 'name': 'cvxpy/cvxpy', 'url': 'https://api.github.com/repos/cvxpy/cvxpy'}
# C:\Users\Guilherme\AppData\Local\Temp\ipykernel_8308\997953705.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   python_repositories_df = python_repositories_df.append(repo_data, ignore_index=True)
# {'id': 607478468, 'name': 'GyrmyzyK30/2696228357141391625', 'url': 'https://api.github.com/repos/GyrmyzyK30/2696228357141391625'}
# Error querying repository languages: Could not resolve to a Repository with the name 'GyrmyzyK30/2696228357141391625'.
# {'id': 619956985, 'name': 'tseladev/maven-web-application', 'url': 'https://api.github.com/repos/tseladev/maven-web-application'}
# {'id': 622033043, 'name': 'rustgen/fast_food_delivery', 'url': 'https://api.github.com/repos/rustgen/fast_food_delivery'}
# {'id': 617597198, 'name': 'CetinMutluOnal/DiemSocial-Backend', 'url': 'https://api.github.com/repos/CetinMutluOnal/DiemSocial-Backend'}
# {'id': 91575249, 'name': 'Lombiq/OrchardCore', 'url': 'https://api.github.com/repos/Lombiq/OrchardCore'}
# {'id': 105813195, 'name': 'diging/monitor', 'url': 'https://api.github.com/repos/diging/monitor'}
# {'id': 542710804, 'name': '499CSpeaking/SpeakingPortal', 'url': 'https://api.github.com/repos/499CSpeaking/SpeakingPortal'}
# C:\Users\Guilherme\AppData\Local\Temp\ipykernel_8308\997953705.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   python_repositories_df = python_repositories_df.append(repo_data, ignore_index=True)
# {'id': 442527373, 'name': 'Superalgos/Governance-Plugins', 'url': 'https://api.github.com/repos/Superalgos/Governance-Plugins'}
# {'id': 383940088, 'name': 'ShadowMario/FNF-PsychEngine', 'url': 'https://api.github.com/repos/ShadowMario/FNF-PsychEngine'}
# {'id': 155930194, 'name': 'NREL/OpenStudio-HPXML', 'url': 'https://api.github.com/repos/NREL/OpenStudio-HPXML'}
# C:\Users\Guilherme\AppData\Local\Temp\ipykernel_8308\997953705.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   python_repositories_df = python_repositories_df.append(repo_data, ignore_index=True)
# {'id': 577430550, 'name': 'husainazkas/husainazkas.github.io', 'url': 'https://api.github.com/repos/husainazkas/husainazkas.github.io'}
# {'id': 439517659, 'name': 'hackernews-archive/hackernews-top-stories', 'url': 'https://api.github.com/repos/hackernews-archive/hackernews-top-stories'}
# {'id': 618870367, 'name': 'maxmielchen/Sailbox', 'url': 'https://api.github.com/repos/maxmielchen/Sailbox'}
# {'id': 481452780, 'name': 'mo9a7i/time_now', 'url': 'https://api.github.com/repos/mo9a7i/time_now'}
# {'id': 86929735, 'name': 'Lombiq/Orchard', 'url': 'https://api.github.com/repos/Lombiq/Orchard'}
# {'id': 336102115, 'name': 'ethyca/fides', 'url': 'https://api.github.com/repos/ethyca/fides'}
# C:\Users\Guilherme\AppData\Local\Temp\ipykernel_8308\997953705.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   python_repositories_df = python_repositories_df.append(repo_data, ignore_index=True)
# {'id': 516108415, 'name': 'flathub/net.brinkervii.grapejuice', 'url': 'https://api.github.com/repos/flathub/net.brinkervii.grapejuice'}
# {'id': 565677420, 'name': 'ChrisF03/Portfolio-Projects', 'url': 'https://api.github.com/repos/ChrisF03/Portfolio-Projects'}
# C:\Users\Guilherme\AppData\Local\Temp\ipykernel_8308\997953705.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   python_repositories_df = python_repositories_df.append(repo_data, ignore_index=True)
# {'id': 512850650, 'name': 'bitcoinsit/CloudServiceIPs', 'url': 'https://api.github.com/repos/bitcoinsit/CloudServiceIPs'}
# {'id': 456055010, 'name': 'Mansur9/startJava', 'url': 'https://api.github.com/repos/Mansur9/startJava'}
# {'id': 577430550, 'name': 'husainazkas/husainazkas.github.io', 'url': 'https://api.github.com/repos/husainazkas/husainazkas.github.io'}
# {'id': 14812739, 'name': 'libuv/libuv', 'url': 'https://api.github.com/repos/libuv/libuv'}
# C:\Users\Guilherme\AppData\Local\Temp\ipykernel_8308\997953705.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   python_repositories_df = python_repositories_df.append(repo_data, ignore_index=True)
# {'id': 621556145, 'name': 'tuckerpikula/portfolio', 'url': 'https://api.github.com/repos/tuckerpikula/portfolio'}
# {'id': 620101262, 'name': 'Dtaylor1333/Chrea', 'url': 'https://api.github.com/repos/Dtaylor1333/Chrea'}
# {'id': 210716005, 'name': 'dotnet/runtime', 'url': 'https://api.github.com/repos/dotnet/runtime'}
# C:\Users\Guilherme\AppData\Local\Temp\ipykernel_8308\997953705.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   python_repositories_df = python_repositories_df.append(repo_data, ignore_index=True)
# {'id': 537202734, 'name': 'jpgard/tableshift', 'url': 'https://api.github.com/repos/jpgard/tableshift'}
# Error querying repository languages: Could not resolve to a Repository with the name 'jpgard/tableshift'.
# {'id': 611617514, 'name': 'mikelgoti/POKEMON', 'url': 'https://api.github.com/repos/mikelgoti/POKEMON'}
# Error querying repository languages: Could not resolve to a Repository with the name 'mikelgoti/POKEMON'.
# {'id': 454400171, 'name': 'yeolip/data_parsing_and_notify_with_timestamps', 'url': 'https://api.github.com/repos/yeolip/data_parsing_and_notify_with_timestamps'}
#                   id               type  \
# 0                NaN                NaN
# 1                NaN                NaN
# 2                NaN                NaN
# 3                NaN                NaN
# 4                NaN                NaN
# ...              ...                ...
# 183000  2.813145e+10        IssuesEvent
# 183001  2.813145e+10          PushEvent
# 183002  2.813145e+10          PushEvent
# 183003  2.813145e+10  IssueCommentEvent
# 183004  2.813145e+10   PullRequestEvent
#
#                                                     actor  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 183000  {'id': 5861765, 'login': 'shorowit', 'display_...
# 183001  {'id': 2092272, 'login': 'galvana', 'display_l...
# 183002  {'id': 103148784, 'login': 'ChrisF03', 'displa...
# 183003  {'id': 289174, 'login': 'trevnorris', 'display...
# 183004  {'id': 19562826, 'login': 'StephenMolloy', 'di...
#
#                                                      repo  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 183000  {'id': 155930194, 'name': 'NREL/OpenStudio-HPX...
# 183001  {'id': 336102115, 'name': 'ethyca/fides', 'url...
# 183002  {'id': 565677420, 'name': 'ChrisF03/Portfolio-...
# 183003  {'id': 14812739, 'name': 'libuv/libuv', 'url':...
# 183004  {'id': 210716005, 'name': 'dotnet/runtime', 'u...
#
#                                                   payload public  \
# 0                                                     NaN    NaN
# 1                                                     NaN    NaN
# 2                                                     NaN    NaN
# 3                                                     NaN    NaN
# 4                                                     NaN    NaN
# ...                                                   ...    ...
# 183000  {'action': 'opened', 'issue': {'url': 'https:/...   True
# 183001  {'repository_id': 336102115, 'push_id': 131509...   True
# 183002  {'repository_id': 565677420, 'push_id': 131509...   True
# 183003  {'action': 'created', 'issue': {'url': 'https:...   True
# 183004  {'action': 'closed', 'number': 76436, 'pull_re...   True
#
#                       created_at  \
# 0                            NaT
# 1                            NaT
# 2                            NaT
# 3                            NaT
# 4                            NaT
# ...                          ...
# 183000 2023-04-01 00:00:01+00:00
# 183001 2023-04-01 00:00:01+00:00
# 183002 2023-04-01 00:00:01+00:00
# 183003 2023-04-01 00:00:01+00:00
# 183004 2023-04-01 00:00:01+00:00
#
#                                                       org
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 183000  {'id': 1906800, 'login': 'NREL', 'gravatar_id'...
# 183001  {'id': 50628321, 'login': 'ethyca', 'gravatar_...
# 183002                                                NaN
# 183003  {'id': 4030929, 'login': 'libuv', 'gravatar_id...
# 183004  {'id': 9141961, 'login': 'dotnet', 'gravatar_i...
#
# [183005 rows x 8 columns]

# %%
python_repositories_df
# Out:
#                   id               type  \
# 0                NaN                NaN
# 1                NaN                NaN
# 2                NaN                NaN
# 3                NaN                NaN
# 4                NaN                NaN
# ...              ...                ...
# 183000  2.813145e+10        IssuesEvent
# 183001  2.813145e+10          PushEvent
# 183002  2.813145e+10          PushEvent
# 183003  2.813145e+10  IssueCommentEvent
# 183004  2.813145e+10   PullRequestEvent
#
#                                                     actor  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 183000  {'id': 5861765, 'login': 'shorowit', 'display_...
# 183001  {'id': 2092272, 'login': 'galvana', 'display_l...
# 183002  {'id': 103148784, 'login': 'ChrisF03', 'displa...
# 183003  {'id': 289174, 'login': 'trevnorris', 'display...
# 183004  {'id': 19562826, 'login': 'StephenMolloy', 'di...
#
#                                                      repo  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 183000  {'id': 155930194, 'name': 'NREL/OpenStudio-HPX...
# 183001  {'id': 336102115, 'name': 'ethyca/fides', 'url...
# 183002  {'id': 565677420, 'name': 'ChrisF03/Portfolio-...
# 183003  {'id': 14812739, 'name': 'libuv/libuv', 'url':...
# 183004  {'id': 210716005, 'name': 'dotnet/runtime', 'u...
#
#                                                   payload public  \
# 0                                                     NaN    NaN
# 1                                                     NaN    NaN
# 2                                                     NaN    NaN
# 3                                                     NaN    NaN
# 4                                                     NaN    NaN
# ...                                                   ...    ...
# 183000  {'action': 'opened', 'issue': {'url': 'https:/...   True
# 183001  {'repository_id': 336102115, 'push_id': 131509...   True
# 183002  {'repository_id': 565677420, 'push_id': 131509...   True
# 183003  {'action': 'created', 'issue': {'url': 'https:...   True
# 183004  {'action': 'closed', 'number': 76436, 'pull_re...   True
#
#                       created_at  \
# 0                            NaT
# 1                            NaT
# 2                            NaT
# 3                            NaT
# 4                            NaT
# ...                          ...
# 183000 2023-04-01 00:00:01+00:00
# 183001 2023-04-01 00:00:01+00:00
# 183002 2023-04-01 00:00:01+00:00
# 183003 2023-04-01 00:00:01+00:00
# 183004 2023-04-01 00:00:01+00:00
#
#                                                       org
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 183000  {'id': 1906800, 'login': 'NREL', 'gravatar_id'...
# 183001  {'id': 50628321, 'login': 'ethyca', 'gravatar_...
# 183002                                                NaN
# 183003  {'id': 4030929, 'login': 'libuv', 'gravatar_id...
# 183004  {'id': 9141961, 'login': 'dotnet', 'gravatar_i...
#
# [183005 rows x 8 columns]
